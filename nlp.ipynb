# %%
# pip install spacy nltk
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 991.0 kB/s eta 0:00:13
#      ---------------------------------------- 0.1/12.8 MB 1.1 MB/s eta 0:00:13
#      ---------------------------------------- 0.1/12.8 MB 1.1 MB/s eta 0:00:13
#      --------------------------------------- 0.1/12.8 MB 599.1 kB/s eta 0:00:22
#       -------------------------------------- 0.2/12.8 MB 860.2 kB/s eta 0:00:15
#       -------------------------------------- 0.3/12.8 MB 930.9 kB/s eta 0:00:14
#      - -------------------------------------- 0.4/12.8 MB 1.0 MB/s eta 0:00:12
#      - -------------------------------------- 0.4/12.8 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.4/12.8 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.4/12.8 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.4/12.8 MB 1.1 MB/s eta 0:00:12
# ...

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text= nlp('is a free, open-source Python library that provides advanced capabilities to conduct natural language processing (NLP) on large volumes of text at high speed. It helps you build models and production applications that can underpin document analysis, chatbot capabilities, and all other forms of text analysis.')

# %%
for i in text.sents:
    print(i)
# Out:
# is a free, open-source Python library that provides advanced capabilities to conduct natural language processing (NLP) on large volumes of text at high speed.
# It helps you build models and production applications that can underpin document analysis, chatbot capabilities, and all other forms of text analysis.

# %%
t=nlp("Mr.Ajay is very intelligent .he is 22 year old . he is soldier in indian army.")

# %%
t1="Mr.Ajay is very intelligent. he is 22 year old. he is soldier in indian army. "
t1.split('.')
# Out:
# ['Mr',
#  'Ajay is very intelligent',
#  ' he is 22 year old',
#  ' he is soldier in indian army',
#  ' ']

# %%
for i in t.sents:
    print(i)
# Out:
# Mr.Ajay is very intelligent .he
# is 22 year old .
# he is soldier in indian army.

# %%
for i in t.sents:
    for j in i:
        print(j)
# Out:
# Mr.
# Ajay
# is
# very
# intelligent
# .he
# is
# 22
# year
# old
# .
# he
# is
# soldier
# in
# indian
# army
# .

# %%
data=nlp('My gmail id is 8122003priyanka@gmail.com and other id is priyankachoudhary0847@gmail.com and nansi0157@yahoo.com')

# %%
for i in data:
   if i.like_email:
    print(i)
# Out:
# 8122003priyanka@gmail.com
# priyankachoudhary0847@gmail.com
# nansi0157@yahoo.com

# %%
for i in t:
    print(i,"POS is",i.pos_,spacy.explain(i.pos_))
# Out:
# Mr. POS is PROPN proper noun
# Ajay POS is PROPN proper noun
# is POS is AUX auxiliary
# very POS is ADV adverb
# intelligent POS is ADJ adjective
# .he POS is NUM numeral
# is POS is AUX auxiliary
# 22 POS is NUM numeral
# year POS is NOUN noun
# old POS is ADJ adjective
# . POS is PUNCT punctuation
# he POS is PRON pronoun
# is POS is AUX auxiliary
# soldier POS is NOUN noun
# in POS is ADP adposition
# indian POS is ADJ adjective
# army POS is NOUN noun
# . POS is PUNCT punctuation
